# %%
import time
from datetime import datetime as dt
from datetime import timedelta as td

timestamp_now = time.time() # timestamp 형식으로 현재 시간 알아오기
print(timestamp_now)
datetime_now = datetime.now() # datetime 형식으로 현재 시간 알아오기
print(datetime_now)

# %%
datetime.now()

# %%
datetime.now().year

# %%
today=datetime.today()
time_delta=timedelta(days=730)
targetday = today - time_delta
d=targetday.replace(day=1)

print(d)

# %%
dt.strftime(d,"%Y-%m-%d")

# %%
today = dt.today()
time_delta = td(days=730)
firstday = (today - time_delta).replace(day=1)
start = dt.strftime(firstday,"%Y-%m-%d")
start

# %%
import time
import datetime as dt

today = dt.datetime.today()
time_delta = dt.timedelta(days=730)
firstday = (today - time_delta).replace(day=1)
start = dt.datetime.strftime(firstday,"%Y-%m-%d")
start
# Out:
# '2016-04-01'

# %%
time_delta = td(days=730)

# %%
import pandas as pd
import numpy as np
sample = pd.read_csv("C:/0.bigData/4.web/Triple_Core/0.DataRepo/0.LocalStorage/symbol_info.csv")
sample = pd.DataFrame(sample)
exchange_info = pd.read_csv("C:/0.bigdata/4.web/Triple_Core/0.DataRepo/0.LocalStorage/exchange_info.csv")

# %%
sample
# Out:
#                                     Name  Symbol     Exchange Sector  \
# 0                   Baoshan Iron & Steel  600019          상하이  기초 소재
# 1                     China Molybdenum A  603993          상하이  기초 소재
# 2                        Wanhua Chemical  600309          상하이  기초 소재
# 3            Inner Mongolia BaoTou Steel  600010          상하이  기초 소재
# 4                         Zijin Mining A  601899          상하이  기초 소재
# 5                            Kangdexin A    2450           심천  기초 소재
# 6                 Zhejiang Huayou Cobalt  603799          상하이  기초 소재
# 7                 Aluminum Corp of China  601600          상하이  기초 소재
# 8                       Tianqi Lithium A    2466           심천  기초 소재
# 9                      Ganfeng Lithium A    2460           심천  기초 소재
# 10           Beijing Sanju Environmental  300072           심천  기초 소재
# 11                           Rongsheng A    2493           심천  기초 소재
# 12              Zhejiang Transfar Co Ltd    2010           심천  기초 소재
# 13                  Shandong Gold Mining  600547          상하이  기초 소재
# 14                      Jiangxi Copper A  600362          상하이  기초 소재
# 15     China Northern Rare Earth Hi-Tech  600111          상하이  기초 소재
# 16                     Baiyin Nonferrous  601212          상하이  기초 소재
# 17                        Angang Steel A     898           심천  기초 소재
# 18                    Hengyi Petrochem A     703           심천  기초 소재
# 19            Junzheng Energy & Chemical  601216          상하이  기초 소재
# 20         Hubei Biocause Pharmaceutical     627           심천  기초 소재
# 21                 Kingray New Materials  600390          상하이  기초 소재
# 22                    Billions Chemicl A    2601           심천  기초 소재
# 23                Zhejiang Sanhua Co Ltd    2050           심천  기초 소재
# 24                         Hebei Steel A     709           심천  기초 소재
# 25                    Idc Fluidcontrol A    2468           심천  기초 소재
# 26                Jiangsu Zhongtian Tech  600522          상하이  기초 소재
# 27                    Zhejiang Longsheng  600352          상하이  기초 소재
# 28                     Jiangsu Shagang A    2075           심천  기초 소재
# 29                    Qinghai Saltlake A     792           심천  기초 소재
# ...                                  ...     ...          ...    ...
# 25642                     TransAlta Corp     TAC           뉴욕   유틸러티
# 25643                         Chesapeake     CPK           뉴욕   유틸러티
# 25644                           SJW Corp     SJW           뉴욕   유틸러티
# 25645         8Point3 Energy Partners LP    CAFD          나스닥   유틸러티
# 25646                         Sunrun Inc     RUN          나스닥   유틸러티
# 25647                     Kenon Holdings     KEN           뉴욕   유틸러티
# 25648                     Connect. Water    CTWS          나스닥   유틸러티
# 25649                        UNITIL Corp     UTL           뉴욕   유틸러티
# 25650                    Middlesex Water    MSEX          나스닥   유틸러티
# 25651                         Nextdecade    NEXT          나스닥   유틸러티
# 25652                   Vivint Solar Inc    VSLR           뉴욕   유틸러티
# 25653                   Spark Energy Inc    SPKE          나스닥   유틸러티
# 25654                     The York Water    YORW          나스닥   유틸러티
# 25655                 Azure Power Global    AZRE           뉴욕   유틸러티
# 25656                       Artesian Res   ARTNA          나스닥   유틸러티
# 25657               Aquaventure Holdings    WAAS           뉴욕   유틸러티
# 25658                              Cadiz    CDZI          나스닥   유틸러티
# 25659                     Atlantic Power      AT           뉴욕   유틸러티
# 25660                          Gas Ships    DGAS          나스닥   유틸러티
# 25661                  RGC Resources Inc    RGCO          나스닥   유틸러티
# 25662                       Global Water    GWRS          나스닥   유틸러티
# 25663                  US Geothermal Inc     HTM           뉴욕   유틸러티
# 25664                     Centrus Energy     LEU           뉴욕   유틸러티
# 25665                     VivoPower Intl    VVPR          나스닥   유틸러티
# 25666                        Juhl Energy    JUHL  OTC Markets   유틸러티
# 25667                   Two Rivers Water    TURV  OTC Markets   유틸러티
# 25668                        Blue Sphere    BLSP  OTC Markets   유틸러티
# 25669                Garb Oil & Pwr Corp    GARB  OTC Markets   유틸러티
# 25670               Biofuels Power Corp.    BFLS  OTC Markets   유틸러티
# 25671                   Dong Fang Hui Le    DFHL  OTC Markets   유틸러티
#
#                Industry
# 0                 철과 철강
# 1                 금속 광업
# 2      화학 제품 – 플라스틱과 고무
# 3                 철과 철강
# 4                  금과 은
# 5              컨테이너와 포장
# 6                 금속 광업
# 7                 금속 광업
# 8                  화학제조
# 9                 금속 광업
# 10                 화학제조
# 11     화학 제품 – 플라스틱과 고무
# 12                 화학제조
# 13                 금과 은
# 14                금속 광업
# 15                금속 광업
# 16             다종 조립 제품
# 17                철과 철강
# 18     화학 제품 – 플라스틱과 고무
# 19     화학 제품 – 플라스틱과 고무
# 20                 화학제조
# 21                금속 광업
# 22                 화학제조
# 23             다종 조립 제품
# 24                철과 철강
# 25             다종 조립 제품
# 26             다종 조립 제품
# 27                 화학제조
# 28             다종 조립 제품
# 29               비금속 광업
# ...                 ...
# 25642           전기 유틸러티
# 25643         천연가스 유틸러티
# 25644           수도 유틸러티
# 25645           전기 유틸러티
# 25646           전기 유틸러티
# 25647           전기 유틸러티
# 25648           수도 유틸러티
# 25649           전기 유틸러티
# 25650           수도 유틸러티
# 25651         천연가스 유틸러티
# 25652           전기 유틸러티
# 25653         천연가스 유틸러티
# 25654           수도 유틸러티
# 25655           전기 유틸러티
# 25656           수도 유틸러티
# 25657           수도 유틸러티
# 25658           수도 유틸러티
# 25659           전기 유틸러티
# 25660         천연가스 유틸러티
# 25661         천연가스 유틸러티
# 25662           수도 유틸러티
# 25663           전기 유틸러티
# 25664           전기 유틸러티
# 25665           전기 유틸러티
# 25666           전기 유틸러티
# 25667           수도 유틸러티
# 25668           전기 유틸러티
# 25669           전기 유틸러티
# 25670           전기 유틸러티
# 25671           전기 유틸러티
#
# [25672 rows x 5 columns]

# %%
exchange = sample.loc[sample['Symbol'] == '2460','Exchange']
exchange.values
# Out:
# array(['심천', '서울', '대만'], dtype=object)

# %%
sample.iloc[14255]
# Out:
# Name          화성산업
# Symbol        2460
# Exchange        서울
# Sector         자본재
# Industry    건설 서비스
# Name: 14255, dtype: object

# %%
sample.iloc[18636]
# Out:
# Name        Gem Terminal
# Symbol              2460
# Exchange              대만
# Sector             테크놀로지
# Industry      전자 장비와 제어기
# Name: 18636, dtype: object

# %%
param_x = exchange_info.loc[exchange_info['Exchange'] == str(exchange)]
param_x = param_x.values.tolist()
print(param_x)
param['c'] = exchange_info.loc[exchange_info['Exchange'] == str(param['x']),'Currency']

# %%
import datetime as dt

today = dt.datetime.today()
end = dt.datetime.strftime(today,"%Y-%m-%d")
end
# Out:
# '2018-04-04'

# %%
end = dt.date.today()
end
# Out:
# datetime.date(2018, 4, 4)
